# %%
import json
import os
import numpy as np

# %%
with open("data\\new_test_json\\test.json", "r") as file:
    test_anno = json.load(file)

# %%
print(test_anno["annotations"])
# Out:
# [{'num_keypoints': 21, 'keypoints': [154, 393, 2, 169, 424, 2, 197, 463, 2, 235, 405, 2, 261, 431, 2, 281, 515, 2, 266, 487, 2, 271, 518, 2, 260, 514, 2, 256, 544, 2, 227, 532, 2, 206, 557, 2, 324, 494, 2, 223, 617, 2, 169, 681, 2, 163, 616, 2, 189, 627, 2, 218, 640, 2, 155, 642, 2, 177, 651, 2, 206, 667, 2], 'image_id': 0, 'bbox': [95, 275, 293, 427], 'category_id': 1, 'id': 0, 'area': 125111}, {'num_keypoints': 21, 'keypoints': [167, 394, 2, 161, 426, 2, 174, 463, 2, 219, 400, 2, 289, 421, 2, 296, 506, 2, 220, 470, 2, 225, 489, 2, 207, 495, 2, 194, 535, 2, 173, 525, 2, 151, 558, 2, 359, 483, 2, 214, 609, 2, 128, 678, 2, 129, 626, 2, 162, 631, 2, 201, 641, 2, 113, 648, 2, 147, 653, 2, 181, 665, 2], 'image_id': 1, 'bbox': [67, 267, 348, 471], 'category_id': 1, 'id': 1, 'area': 163908}, {'num_keypoints': 21, 'keypoints': [153, 385, 2, 166, 416, 2, 185, 448, 2, 225, 383, 2, 253, 408, 2, 275, 502, 2, 250, 482, 2, 274, 500, 2, 249, 498, 2, 261, 531, 2, 240, 526, 2, 208, 557, 2, 322, 495,
# ...

# %%
for i in test_anno["annotations"]:
    i['iscrowd'] = 0

# %%
print(test_anno["annotations"])
# Out:
# [{'num_keypoints': 21, 'keypoints': [154, 393, 2, 169, 424, 2, 197, 463, 2, 235, 405, 2, 261, 431, 2, 281, 515, 2, 266, 487, 2, 271, 518, 2, 260, 514, 2, 256, 544, 2, 227, 532, 2, 206, 557, 2, 324, 494, 2, 223, 617, 2, 169, 681, 2, 163, 616, 2, 189, 627, 2, 218, 640, 2, 155, 642, 2, 177, 651, 2, 206, 667, 2], 'image_id': 0, 'bbox': [95, 275, 293, 427], 'category_id': 1, 'id': 0, 'area': 125111, 'iscrowd': 0}, {'num_keypoints': 21, 'keypoints': [167, 394, 2, 161, 426, 2, 174, 463, 2, 219, 400, 2, 289, 421, 2, 296, 506, 2, 220, 470, 2, 225, 489, 2, 207, 495, 2, 194, 535, 2, 173, 525, 2, 151, 558, 2, 359, 483, 2, 214, 609, 2, 128, 678, 2, 129, 626, 2, 162, 631, 2, 201, 641, 2, 113, 648, 2, 147, 653, 2, 181, 665, 2], 'image_id': 1, 'bbox': [67, 267, 348, 471], 'category_id': 1, 'id': 1, 'area': 163908, 'iscrowd': 0}, {'num_keypoints': 21, 'keypoints': [153, 385, 2, 166, 416, 2, 185, 448, 2, 225, 383, 2, 253, 408, 2, 275, 502, 2, 250, 482, 2, 274, 500, 2, 249, 498, 2, 261, 531, 2, 240, 52
# ...

# %%
with open("data\\new_test_json\\test.json", "w") as b_file:
    json.dump(test_anno, b_file,indent=4)
